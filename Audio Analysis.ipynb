# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
from dtw import dtw

#Loading audio files
y1, sr1 = librosa.load('Raag-Yaman-Chalan-1.wav') 
y2, sr2 = librosa.load('mel-gen-11.wav') 

#Showing multiple plots using subplot
plt.subplot(1, 2, 1) 
mfcc1 = librosa.feature.mfcc(y1,sr1)   #Computing MFCC values
librosa.display.specshow(mfcc1)

plt.subplot(1, 2, 2)
mfcc2 = librosa.feature.mfcc(y2, sr2)
librosa.display.specshow(mfcc2)

# %%
from numpy.linalg import norm
dist, cost,acc_cost, path = dtw(mfcc1.T, mfcc2.T, dist=lambda x, y: norm(x - y, ord=1))
print("The normalized distance between the two : ",dist)   # 0 for similar audios 

plt.imshow(cost.T, origin='lower', cmap=plt.get_cmap('gray'), interpolation='nearest',aspect='auto')

plt.plot(path[0], path[1], 'w')   #creating plot for DTW

plt.show()  #To display the plots graphically
# Out:
# The normalized distance between the two :  292926.60717868805

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
from dtw import dtw

#Loading audio files
y1, sr1 = librosa.load('Raag-Yaman-Chalan-1.wav') 
y2, sr2 = librosa.load('generated-melody-5.wav') 

#Showing multiple plots using subplot
plt.subplot(1, 2, 1) 
mfcc1 = librosa.feature.mfcc(y1,sr1)   #Computing MFCC values
librosa.display.specshow(mfcc1)

plt.subplot(1, 2, 2)
mfcc2 = librosa.feature.mfcc(y2, sr2)
librosa.display.specshow(mfcc2)

# %%
from numpy.linalg import norm
dist, cost,acc_cost, path = dtw(mfcc1.T, mfcc2.T, dist=lambda x, y: norm(x - y, ord=1))
print("The normalized distance between the two : ",dist)   # 0 for similar audios 

plt.imshow(cost.T, origin='lower', cmap=plt.get_cmap('gray'), interpolation='nearest',aspect='auto')

plt.plot(path[0], path[1], 'w')   #creating plot for DTW

plt.show()  #To display the plots graphically
# Out:
# The normalized distance between the two :  230175.30950772762

# %%
# %load_ext autoreload
# %autoreload 1
from python.AudioAnalyzer import *
# %aimport python.AudioAnalyzer

# %%
original = AudioAnalyzer("Raag-Yaman-Chalan-1.wav")
remaster_09 = AudioAnalyzer("generated-melody-5.wav")

# %%
original.plot_spectrum(min_freq=20, max_freq=1000, title="Original")
remaster_09.plot_spectrum(min_freq=20, max_freq=1000, title="Generated")

# %%
orig_to_09 = SpectrumCompare(original, remaster_09)
#orig_to_15 = SpectrumCompare(original, remaster_15)

# %%
orig_to_09.plot_spectrum_group(frange=(20,1000), 
    ratio=True, 
    threshold=True,
    title="Spectrograms - original vs generated (with threshold)", 
    legend=("Original", "Remaster", "Amplitude Diff.", "Threshold")
    )

orig_to_09.plot_spectrum_heatmap(
    frange=(20,1000), 
    plot_spec1=False,
    title="Original vs generated"
)
orig_to_09.plot_spectrum_heatmap(
    frange=(20,500), 
    plot_spec1=False, 
    title="Original vs generated"
)

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
from dtw import dtw

#Loading audio files
y1, sr1 = librosa.load('Raag yaman swarmalika.wav') 
y2, sr2 = librosa.load('sitar-melody-10-trimmed.wav') 

#Showing multiple plots using subplot
plt.subplot(1, 2, 1) 
mfcc1 = librosa.feature.mfcc(y1,sr1)   #Computing MFCC values
librosa.display.specshow(mfcc1)

plt.subplot(1, 2, 2)
mfcc2 = librosa.feature.mfcc(y2, sr2)
librosa.display.specshow(mfcc2)

# %%
from numpy.linalg import norm
dist, cost,acc_cost, path = dtw(mfcc1.T, mfcc2.T, dist=lambda x, y: norm(x - y, ord=1))
print("The normalized distance between the two : ",dist)   # 0 for similar audios 

plt.imshow(cost.T, origin='lower', cmap=plt.get_cmap('gray'), interpolation='nearest',aspect='auto')

plt.plot(path[0], path[1], 'w')   #creating plot for DTW

plt.show()  #To display the plots graphically
# Out:
# The normalized distance between the two :  309171.0679130554

# %%
# %load_ext autoreload
# %autoreload 1
from python.AudioAnalyzer import *
# %aimport python.AudioAnalyzer

# %%
original = AudioAnalyzer("Raag yaman swarmalika.wav")
remaster_09 = AudioAnalyzer("sitar-melody-10-trimmed.wav")

# %%
original.plot_spectrum(min_freq=20, max_freq=1000, title="Original")
remaster_09.plot_spectrum(min_freq=20, max_freq=1000, title="Generated")

# %%
orig_to_09 = SpectrumCompare(original, remaster_09)
#orig_to_15 = SpectrumCompare(original, remaster_15)

# %%
orig_to_09.plot_spectrum_group(frange=(20,4000), 
    ratio=True, 
    threshold=True,
    title="Spectrograms - original vs generated (with threshold)", 
    legend=("Original", "Generated", "Amplitude Diff.", "Threshold")
    )

orig_to_09.plot_spectrum_heatmap(
    frange=(20,4000), 
    plot_spec1=False,
    title="Original vs Generated"
)
orig_to_09.plot_spectrum_heatmap(
    frange=(20,3000), 
    plot_spec1=False, 
    title="Original vs Generated"
)

# %%
import argparse

# %%
orig_to_09.plot_spectrum_group(
    frange=(20,4000), 
    title="Spectrograms - Original vs Generated", 
    legend=("Original", "Generated")
    )

# %%
orig_to_09.plot_amplitude_distributions(title="Original vs Generated")
# Out:
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
#    T-Statistic  P-Value
# 0  -762.600882      0.0

# %%
orig_to_09.plot_spectrum_group(frange=(20,1000), 
    ratio=True, 
    threshold=True,
    title="Original vs Generated",
    legend=("Original", "Generated", "Amplitude Diff.", "Threshold")
    )

orig_to_09.plot_spectrum_heatmap(frange=(20,500), 
    plot_spec1=False, 
    cmap='magma',
    title="Original vs Generated Heatmap (20-500 Hz)"
    )
